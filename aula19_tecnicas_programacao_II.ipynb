# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/Algoritmos/blob/main/aula19_tecnicas_programacao_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Técnicas de Programação II
# ## Aula 19 — Finalização do Projeto
#
# Projeto do semestre:
#
# ## 🛒 Sistema de Catálogo de Produtos
#
# Durante o semestre desenvolvemos um sistema completo utilizando diversas tecnologias.
#
# Nesta aula iremos **organizar, revisar e preparar o projeto para entrega final**.

# %% [markdown]
# # 🎯 Objetivos da Aula
#
# Ao final desta aula você deverá:
#
# - revisar o funcionamento completo do sistema
# - corrigir possíveis erros
# - organizar o repositório do projeto
# - preparar o projeto para apresentação final

# %% [markdown]
# # 🔁 Revisão do Projeto
#
# Nosso sistema possui as seguintes funcionalidades:
#
# - cadastro de produtos
# - edição de produtos
# - exclusão de produtos
# - listagem de produtos
# - busca de produtos
# - paginação de resultados

# %% [markdown]
# # 🧱 Tecnologias Utilizadas
#
# Durante o desenvolvimento utilizamos:
#
# - Python
# - Flask
# - SQLAlchemy
# - Bootstrap
# - HTML / CSS
# - Git e GitHub

# %% [markdown]
# # 📂 Estrutura Final do Projeto

# %%
projeto/

app.py

models/
    produto.py

controllers/
    produto_controller.py

repositories/
    produto_repository.py

factories/
    produto_factory.py

templates/
    base.html
    produtos.html
    novo_produto.html

static/
    css/

# %% [markdown]
# # ✔ Checklist de Verificação
#
# Antes da entrega verifique se:
#
# - o sistema executa sem erros
# - todas as rotas funcionam
# - cadastro de produtos funciona
# - edição de produtos funciona
# - exclusão funciona
# - busca funciona
# - paginação funciona

# %% [markdown]
# # 🧪 Testando o Sistema
#
# Execute a aplicação:
#
# ```
# python app.py
# ```
#
# Abra o navegador:
#
# ```
# http://localhost:5000
# ```

# %% [markdown]
# # 📦 Dependências do Projeto
#
# Verifique se existe o arquivo:
#
# ```
# requirements.txt
# ```

# %%
Flask
Flask-SQLAlchemy

# %% [markdown]
# Caso não exista, gere automaticamente:
#
# ```
# pip freeze > requirements.txt
# ```

# %% [markdown]
# # 📄 Revisando README.md
#
# Seu README deve conter:
#
# - descrição do projeto
# - tecnologias utilizadas
# - funcionalidades
# - instruções de execução

# %% [markdown]
# # 🌐 Publicação no GitHub
#
# Verifique se o projeto está publicado no GitHub.

# %%
git add .
git commit -m "Versão final do projeto"
git push origin main

# %% [markdown]
# # 🧪 Exercício Guiado
#
# 1. Revise todo o sistema.
# 2. Corrija possíveis erros.
# 3. Atualize o README.
# 4. Atualize o repositório no GitHub.

# %% [markdown]
# # 🧪 Exercícios
#
# ## Exercício 1
# Adicione uma funcionalidade extra ao sistema.
#
# Exemplos:
#
# - campo categoria
# - campo descrição
# - filtro por preço

# %% [markdown]
# ## Exercício 2
# Melhore a interface do sistema utilizando Bootstrap.

# %% [markdown]
# # 🚀 Desafio
#
# Adicione uma nova funcionalidade ao sistema que **não foi vista em aula**.

# %% [markdown]
# # 📌 Conclusão
#
# Nesta aula revisamos todo o sistema desenvolvido durante o semestre
# e preparamos o projeto para entrega e apresentação final.

# %% [markdown]
# # 🔜 Próxima Aula
#
# ## Apresentação dos Projetos
#
# Cada grupo deverá apresentar:
#
# - funcionamento do sistema
# - tecnologias utilizadas
# - principais desafios encontrados
