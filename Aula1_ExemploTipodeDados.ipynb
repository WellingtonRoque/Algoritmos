# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/Algoritmos/blob/main/Aula1_ExemploTipodeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Tipo de dados
#
# Apresentar os principais tipos de dados em Python

# %%
num = 10

nome = "Wel"
idade = 44
num=5
print("O valor do produto: ",num)
print(f"Idade {idade} e nome {nome}")
# Out:
# O valor do produto:  5
# Idade 44 e nome Wel

# %%
#aluno = "pedro"
aluno = input("Digite o seu nome: ")
idade = int(input("Digite a sua idade: "))
altura = float(input("Digite a sua altura: "))

#print("Nome do aluno: ",aluno)
print(f"Nome do aluno: {aluno}")
print("tipo de variavel: ",type(aluno))

print(f"Idade do aluno: {idade}")
print("tipo de variavel: ",type(idade))
print("tipo de variavel: ",type(altura))
# Out:
# Digite o seu nome: wel
# Digite a sua idade: 44
# Digite a sua altura: 1.8
# Nome do aluno: wel
# tipo de variavel:  <class 'str'>
# Idade do aluno: 44
# tipo de variavel:  <class 'int'>
# tipo de variavel:  <class 'float'>

# %%
num1 = float(input("Digite o numero 1: "))
num2 = float(input("Digite o numero 2: "))

media = (num1 + num2) / 2

#print(f"A media é: {(num1+num2)/2}")
print(f"A media é: {media}")
# Out:
# Digite o numero 1: 5
# Digite o numero 2: 5
# A media é: 5.0
